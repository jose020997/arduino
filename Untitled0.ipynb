# %% [markdown]
# <a href="https://colab.research.google.com/github/jose020997/arduino/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
TWILIO_ACCOUNT_SID ='AC7fdf7fea89c62133f237e332fd47ad41'
TWILIO_AUTH_TOKEN ='cd266597aa98210de02c79dbde356fc6'
PHONE_NUMBER ='+1 207 245 1366'
API_KEY_WAPI = '365f8a74f4364803a14115352231310'

# %%
import os
import time

from requests import Request, Session
from requests.exceptions import ConnectionError, Timeout, TooManyRedirects
import json

import pandas as pd
import requests
from bs4  import BeautifulSoup
from tqdm import tqdm

from datetime import datetime

# %%
query = '38.100256, -3.624473' #Valor de las coordenadas de Linares
api_key = API_KEY_WAPI #Valor de la API_KEY
url_clima = 'http://api.weatherapi.com/v1/forecast.json?key='+api_key+'&q='+query+'&days=7&aqi=no&alerts=no' #URL que obtenemos en la pagina w3b

response = requests.get(url_clima).json() #Obtenemos la respuesta de la petición
print(response)
# Out:
# {'location': {'name': 'Linares', 'region': 'Andalucia', 'country': 'Spain', 'lat': 38.1, 'lon': -3.62, 'tz_id': 'Europe/Madrid', 'localtime_epoch': 1697992720, 'localtime': '2023-10-22 18:38'}, 'current': {'last_updated_epoch': 1697992200, 'last_updated': '2023-10-22 18:30', 'temp_c': 20.2, 'temp_f': 68.4, 'is_day': 1, 'condition': {'text': 'Patchy rain possible', 'icon': '//cdn.weatherapi.com/weather/64x64/day/176.png', 'code': 1063}, 'wind_mph': 9.6, 'wind_kph': 15.5, 'wind_degree': 120, 'wind_dir': 'ESE', 'pressure_mb': 998.0, 'pressure_in': 29.47, 'precip_mm': 0.01, 'precip_in': 0.0, 'humidity': 46, 'cloud': 89, 'feelslike_c': 20.2, 'feelslike_f': 68.3, 'vis_km': 10.0, 'vis_miles': 6.0, 'uv': 5.0, 'gust_mph': 17.9, 'gust_kph': 28.7}, 'forecast': {'forecastday': [{'date': '2023-10-22', 'date_epoch': 1697932800, 'day': {'maxtemp_c': 20.0, 'maxtemp_f': 68.0, 'mintemp_c': 11.7, 'mintemp_f': 53.1, 'avgtemp_c': 16.0, 'avgtemp_f': 60.8, 'maxwind_mph': 15.4, 'maxwind_kph': 24.8, 'totalpr
# ...

# %%
response['forecast']['forecastday'][0].keys()
# Out:
# dict_keys(['date', 'date_epoch', 'day', 'astro', 'hour'])

# %%
response['forecast']['forecastday'][2]['hour'] #con el forecastday pones el numero del dia
# Out:
# [{'time_epoch': 1698098400,
#   'time': '2023-10-24 00:00',
#   'temp_c': 15.3,
#   'temp_f': 59.5,
#   'is_day': 0,
#   'condition': {'text': 'Patchy rain possible',
#    'icon': '//cdn.weatherapi.com/weather/64x64/night/176.png',
#    'code': 1063},
#   'wind_mph': 7.2,
#   'wind_kph': 11.5,
#   'wind_degree': 246,
#   'wind_dir': 'WSW',
#   'pressure_mb': 1016.0,
#   'pressure_in': 29.99,
#   'precip_mm': 0.01,
#   'precip_in': 0.0,
#   'humidity': 74,
#   'cloud': 86,
#   'feelslike_c': 15.3,
#   'feelslike_f': 59.5,
#   'windchill_c': 15.3,
#   'windchill_f': 59.5,
#   'heatindex_c': 15.3,
#   'heatindex_f': 59.5,
#   'dewpoint_c': 10.7,
#   'dewpoint_f': 51.2,
#   'will_it_rain': 0,
#   'chance_of_rain': 70,
#   'will_it_snow': 0,
#   'chance_of_snow': 0,
#   'vis_km': 10.0,
#   'vis_miles': 6.0,
#   'gust_mph': 10.9,
#   'gust_kph': 17.5,
#   'uv': 1.0},
#  {'time_epoch': 1698102000,
#   'time': '2023-10-24 01:00',
#   'temp_c': 14.2,
#   'temp_f': 57.6,
#   'is_day': 0,
# ...
